# %% [markdown]
# # Regression Design
#
# In this study, we want to learn how monetary shocks will affect the equity financing cost which is measured by the accumulated abnormal return associated with *filing* and *issuance* event. The regression design is following:
# $$
# \begin{equation}
# AAR^{e}_{i}=\alpha+\beta\cdot MS^{e}_{i}+\gamma\cdot \Gamma^{e,MS}_{i}+\theta\cdot \Theta^{e,MS}_{i}+\psi\cdot \Psi^{e}_{i}+\varepsilon_{i}
# \end{equation}
# $$
# Here, $ i $ is the index for each SEO deal in the sample. $ e $ indexes the type of event, i.e. filing event or issuance event. $ MS^{e}_{i} $ is the measured exposure of deal $ i $'s event $ e $ to monetary shocks. $ \Gamma^{e,MS}_{i} $ is a vector of controls about the macroeconomic conditions which are chosen based on the date of event $ e $, the type of monetary shock exposure measure $ MS $. $ \Theta^{e,MS} $ is a vector of controls about the firm-level conditions which are also chosen based on the date of event $ e $, the type of monetary shock exposure measure $ MS $. $ \Psi^{e}_{i} $ is a vector of controls about the firm-level stock market conditions which are based on the date of event $ e $.

# %% [markdown]
# ## Construction of Regression Variables
#
# 1. $ AAR^{e}_{i} $: the accumulated abnormal return around the date of event $ e $.
#
#     Depending on the choice of event window, there are multiple types of measured accumulated abnormal returns for each event type $ e $ of each deal $ i $.
#
# 2. $ MS^{e}_{i} $
#
#     There are three preferred measures for the exposure of event $ e $ of deal $i$:
#     1. The most previous monetary shock before the event date
#     2. The total sum of the previous monetary shocks which are within the 30-day window before the event date
#     3. The total sum of the previous monetary shocks which are within the 90-day window before the event date
#
#
#     Besides the above three types of measurement used, there are also two types of monetary shocks to be used in this study:
#     1) Monetary shocks identified based on high-frequency price information in the funderal fund rate future market.
#         - Pros: identification is relatively clean
#         - Cons: only available after 1990
#     2) Monetary shocks identified based on Romer and Romer (2004)
#         - Pros: long history, which can be traced back to 1970, given that these shocks are also identified based on the FOMC meeting dates, we disassemble the aggregate shock time-series provided by Wieland and Yang (2018) and recover the monetary shocks at each FOMC meeting date.
#         - Cons: identification could be arguable.
#
# 3. $ \Gamma^{e,MS}_{i} $: macroeconomic controls including the GDP growth rate, unemployment rate, inflation rate, the stock market momentum measured by the return of S\&P 500, and the stock market volatility measured either by VIX or the standard deviation of S\&P 500 daily return rate.
#     - **Timing**: all the macroeconomic variables are the quarterly data items of the quarter before the most previous monetary shock which is included in the measurement $ MS^{e}_{i} $. Since VIX index becomes available only after 1990, the stock market volatility is the preferred measure in this study. The total return and volatility is measured based on the daily return rate of S\&P 500 index within the same quarter of other macroeconomic variables.
#
# 4. $ \Theta^{e,MS}_{i} $: firm-level balance sheet information to control the individual state which are measured with the same timing of the macroeconomic controls and include following variables:
#         1. Leverage ratio
#         2. Ratio of current asset in the total asset
#         3. Size quantile position within the specific quarter within the whole Compustat industrial firm population, or the dummy for being in the top 25\% or bottom 25\% quantile.
#         4. Sale growth rate, or sale growth rate quantile position within the specific quarter within the whole Compustat industrial firm population, or the dummy for being in the top 25\% or bottom 25\% quantile.
#         5. Asset size growth rate, or asset size growth rate quantile position within the specific quarter within the whole Compustat industrial firm population, or the dummy for being in the top 25\% or bottom 25\% quantile.
#
# 5. $ \Psi^{e}_{i} $: firm-level stock market movement information to control the market timing behavior which include the average return and volatility of the abnormal return of each firm within the 75-trading-day window which ends at 5 days before the date of event $ e $.

# %% [markdown]
# ## Important Notes about Sample Period
#
# 0. To be consistent with our aggregate-level evidence, we will only use the observations before 2007Q2 for the analysis.
#
# 1. 1970-1983: within this period, there was only the issuance date information available. The information about the filing date in SDC became available only starting from 1983.
#
# 2. 2000-: starting from 2000, there was an institutional change in SEO issuance and the gap between filing and the actual issuance became longer and longer.
#
# 3. 1993: there could be break point in the high-frequency monetary shocks.

# %% [markdown]
# # Regression Results

# %%
#%% Import Moduels

## System Tools
import os
import numpy as np
## I/O Tools
import _pickle as pickle
## Data Process Tools
import pandas as pd
import datetime
## Graphs
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf as figpdf
import matplotlib.dates as matdates
## Statistical Tools
import statsmodels.api as sm
## Database API
from fredapi import Fred
## API for WRDS
import wrds

# End of Section: Import Moduels
###############################################################################


#%% Setup Working Directory
try:
    # Office Desktop Directory
    os.chdir("E:\\Dropbox")
except:
    # Home Desktop Directory
    os.chdir("L:\Dropbox")
    
#Windows System Path
os.chdir("Research Projects\\EquityMarkets_MonetaryPolicy\\Data\\Micro_data\\codes")

# End of Section: Setup Working Directory
###############################################################################

#%% Temporary Functions for Running the Regressions

### One Single Simple Regression
def TempFun_SingleReg(DS,YVar,XVarList,WeightVar=''):
    if WeightVar=='':
        TempReg     =   sm.OLS(DS[YVar],sm.add_constant(DS[XVarList]), \
                               missing='drop').fit()
    else:
        TempReg     =   sm.OLS(DS[YVar],sm.add_constant(DS[XVarList]), \
                               weights=DS[WeightVar], \
                               missing='drop').fit()
    TempTable   =   pd.concat([pd.DataFrame(TempReg.params,columns=[YVar]), \
                               pd.DataFrame(TempReg.tvalues,columns=[YVar])], \
                              axis=0,keys=['Coef','Tstat']) \
                    .swaplevel(i=0,j=1,axis=0)
    TempTable.loc[('RegInfo','Obs'),YVar]    =   TempReg.nobs
    TempTable.loc[('RegInfo','R2'),YVar]     =   TempReg.rsquared
    
    TempTable.sort_index(inplace=True)
    
    return TempTable,TempReg

### A Single Regression with a Given Regression Setup
def TempFun_GroupUnitReg(DS,DateLimit,IF,RetVar,MsVar,XList_Macro,XList_Firm,XList_IndRet,WeightVar=''):
    YVar            =   IF+'_'+RetVar
    XVar_Ms         =   IF+'_'+MsVar
    XVarList_Macro  =   [XVar_Ms+'_'+x for x in XList_Macro]
    XVarList_Firm   =   [XVar_Ms+'_'+x for x in XList_Firm]
    XVarList_IndRet =   [IF+'_'+x for x in XList_IndRet]
    
    XVarList        =   [XVar_Ms]+XVarList_Macro+XVarList_Firm+XVarList_IndRet
    XLabelList      =   ['Ms']+XList_Macro+XList_Firm+XList_IndRet
    
    if IF=='I':
        DateVar     =   'IssueDate'
    elif IF=='F':
        DateVar     =   'FilingDate'

    TempInd         =   ( DS[DateVar]>=DateLimit[0] ) & ( DS[DateVar]<=DateLimit[1] )
                        
    EffectiveDS     =   DS.loc[TempInd,[YVar]+XVarList].dropna().reset_index(drop=True)
    if EffectiveDS.shape[0]>10:
        RegTable,RegInfo    =   TempFun_SingleReg(EffectiveDS,YVar,XVarList,WeightVar)
        ColTuple            =   (IF,RetVar,MsVar,(DateLimit[0].year,DateLimit[1].year))
        RegTable.rename(columns={YVar: ColTuple},inplace=True)
        RegTable.columns    =   pd.MultiIndex.from_tuples(RegTable.columns.tolist())
        
        RegTable.rename(index={XVarList[i]: XLabelList[i] for i in range(len(XVarList))}, \
                        level=0,inplace=True)
    else:
        RegTable    =   pd.DataFrame()
    
    return RegTable
# End of Section:
###############################################################################

# %%
#%% Benchmark Regression

### Setup

## Read-in Data
DataFolder      =   '..\\temp\\'
DS              =   pickle.load(open(DataFolder+"RegSample.p","rb"))

## Sample Period
SamplePeriodList=   [ [datetime.date(1970,1,1),datetime.date(2007,6,1)], \
                      [datetime.date(1983,1,1),datetime.date(2007,6,1)], \
                      [datetime.date(1993,1,1),datetime.date(2007,6,1)], \
                      [datetime.date(1970,1,1),datetime.date(1999,12,31)], \
                      [datetime.date(1983,1,1),datetime.date(1999,12,31)], \
                      [datetime.date(1993,1,1),datetime.date(1999,12,31)], \
                      [datetime.date(2000,1,1),datetime.date(2007,6,1)], \
                      [datetime.date(1970,1,1),datetime.date(1983,1,1)] \
                    ]

## Variable Lists
RetVar          =   'AccAbRet_-1_1'
MsVarList       =   ['30d_MsRR','90d_MsRR','30d_MsWideHF','90d_MsWideHF']

MacroVarList    =   ['GdpGrowth','Inflation','UnemploymentRate','SpRet_Sum','SpRet_Std']
IndRetVarList   =   ['Runup','AbRetStd']
FirmVarList     =   ['Leverage','OfferedTotalSharesDivByCommonShares_Outstanding', \
                     'SaleGrowth_LowQuant','SaleGrowth_UppQuant', \
                     'Size_LowQuant','Size_UppQuant']
## Regression Design

RegDesignList   =   [{'Macro': [], 'IndRet': [], 'Firm': []}, \
                     {'Macro': MacroVarList,'IndRet': [], 'Firm': []}, \
                     {'Macro': MacroVarList,'IndRet': IndRetVarList, 'Firm': []}, \
                     {'Macro': MacroVarList,'IndRet': IndRetVarList,'Firm': FirmVarList}
                    ]

RegDesignTagList=   range(len(RegDesignList))
### Collect the Regression Results
RegResultTableList  =   []
for RegDesign in RegDesignList:
    InitiateFlag    =   1
    for IF in ['I','F']:
        for MsVar in MsVarList:
            for DateLimit in SamplePeriodList:
                TempTable   =   TempFun_GroupUnitReg(DS,DateLimit,IF,RetVar,MsVar, \
                                                     RegDesign['Macro'], \
                                                     RegDesign['Firm'], \
                                                     RegDesign['IndRet'])
                if not TempTable.empty:
                    if InitiateFlag==1:
                        RegResultTable  =   TempTable
                        InitiateFlag    =   0
                    else:
                        RegResultTable  =   RegResultTable.merge(right=TempTable, \
                                                                 how='outer', \
                                                                 left_index=True, \
                                                                 right_index=True)
    RegResultTableList.append(RegResultTable)

RegResultTable  =   pd.concat(RegResultTableList,join='outer',axis=1, \
                              keys=RegDesignTagList)
RegResultTable.columns \
                =   RegResultTable.columns.droplevel(level=2)
### Clean the Regression Results
idx             =   pd.IndexSlice

## Sort the Vairables for Easier Interpretation
OutputTable     =   RegResultTable.loc[idx[['Ms','const'],:],:] \
                    .append(RegResultTable.loc[idx[MacroVarList,:],:]) \
                    .append(RegResultTable.loc[idx[IndRetVarList,:],:]) \
                    .append(RegResultTable.loc[idx[FirmVarList,:],:]) \
                    .append(RegResultTable.loc[idx['RegInfo',:],:]) 

## Clean the Results for Print
# Filing Date
TempTable_F     =   OutputTable.loc[:,idx[3,'F',['30d_MsWideHF','90d_MsWideHF'],[(1993,2007),(1993,1999),(2000,2007)]]] \
                    .merge( \
                    OutputTable.loc[:,idx[3,'F',['30d_MsRR','90d_MsRR'],[(1983,2007),(1983,1999),(2000,2007)]]], \
                    left_index=True,right_index=True)
TempTable_F.columns \
                =   TempTable_F.columns.droplevel(level=[0,1])
# Issuance Date
TempTable_I     =   OutputTable.loc[:,idx[3,'I',['30d_MsWideHF','90d_MsWideHF'],[(1993,2007),(1993,1999),(2000,2007)]]] \
                    .merge( \
                    OutputTable.loc[:,idx[3,'I',['30d_MsRR','90d_MsRR'],[(1970,2007),(1970,1999),(2000,2007)]]], \
                    left_index=True,right_index=True)
TempTable_I.columns \
                =   TempTable_I.columns.droplevel(level=[0,1])

# End of Section:
###############################################################################

# %% [markdown]
# ## Filing Date Study

# %%
display(np.round(TempTable_F,2))
# Out:
#                                                       30d_MsWideHF  \
#                                                       (1993, 2007)
# Ms                                              Coef         -5.80
#                                                 Tstat        -2.70
# const                                           Coef         -2.52
#                                                 Tstat        -1.59
# GdpGrowth                                       Coef          0.05
#                                                 Tstat         0.78
# Inflation                                       Coef          0.15
#                                                 Tstat         0.62
# SpRet_Std                                       Coef          0.35
#                                                 Tstat         0.69
# SpRet_Sum                                       Coef          0.03
#                                                 Tstat         1.33
# UnemploymentRate                                Coef         -0.05
#                                                 Tstat        -0.27
# AbRetStd                                        Coef         -0.20
#                                                 Tstat        -3.19
# Runup                                           Coef         -0.04
#                                                 Tstat        -6.93
# Leverage                                        Coef         -0.10
#                                                 Tstat        -0.19
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -0.60
# SaleGrowth_LowQuant                             Coef          0.28
#                                                 Tstat         0.71
# SaleGrowth_UppQuant                             Coef         -0.19
#                                                 Tstat        -0.65
# Size_LowQuant                                   Coef          1.27
#                                                 Tstat         1.42
# Size_UppQuant                                   Coef          0.93
#                                                 Tstat         2.77
# RegInfo                                         Obs        2525.00
#                                                 R2            0.04
#
#                                                                     \
#                                                       (1993, 1999)
# Ms                                              Coef         -8.37
#                                                 Tstat        -2.26
# const                                           Coef         -3.92
#                                                 Tstat        -1.62
# GdpGrowth                                       Coef         -0.01
#                                                 Tstat        -0.07
# Inflation                                       Coef          0.80
#                                                 Tstat         1.23
# SpRet_Std                                       Coef          1.42
#                                                 Tstat         1.67
# SpRet_Sum                                       Coef          0.07
#                                                 Tstat         1.92
# UnemploymentRate                                Coef         -0.12
#                                                 Tstat        -0.35
# AbRetStd                                        Coef         -0.16
#                                                 Tstat        -1.63
# Runup                                           Coef         -0.04
#                                                 Tstat        -5.62
# Leverage                                        Coef         -0.67
#                                                 Tstat        -0.90
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -0.54
# SaleGrowth_LowQuant                             Coef          0.10
#                                                 Tstat         0.19
# SaleGrowth_UppQuant                             Coef         -0.27
#                                                 Tstat        -0.72
# Size_LowQuant                                   Coef          1.12
#                                                 Tstat         1.19
# Size_UppQuant                                   Coef          1.29
#                                                 Tstat         2.79
# RegInfo                                         Obs        1386.00
#                                                 R2            0.04
#
#                                                                     \
#                                                       (2000, 2007)
# Ms                                              Coef         -4.73
#                                                 Tstat        -1.72
# const                                           Coef         -3.08
#                                                 Tstat        -1.28
# GdpGrowth                                       Coef          0.07
#                                                 Tstat         0.76
# Inflation                                       Coef          0.20
#                                                 Tstat         0.57
# SpRet_Std                                       Coef         -0.11
#                                                 Tstat        -0.14
# SpRet_Sum                                       Coef         -0.00
#                                                 Tstat        -0.02
# UnemploymentRate                                Coef          0.08
#                                                 Tstat         0.25
# AbRetStd                                        Coef         -0.22
#                                                 Tstat        -2.36
# Runup                                           Coef         -0.03
#                                                 Tstat        -4.07
# Leverage                                        Coef          0.33
#                                                 Tstat         0.44
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -0.45
# SaleGrowth_LowQuant                             Coef          0.39
#                                                 Tstat         0.64
# SaleGrowth_UppQuant                             Coef         -0.07
#                                                 Tstat        -0.15
# Size_LowQuant                                   Coef          2.02
#                                                 Tstat         0.82
# Size_UppQuant                                   Coef          0.65
#                                                 Tstat         1.31
# RegInfo                                         Obs        1139.00
#                                                 R2            0.04
#
#                                                       90d_MsWideHF  \
#                                                       (1993, 2007)
# Ms                                              Coef         -2.79
#                                                 Tstat        -1.95
# const                                           Coef         -3.65
#                                                 Tstat        -2.29
# GdpGrowth                                       Coef          0.07
#                                                 Tstat         1.05
# Inflation                                       Coef          0.50
#                                                 Tstat         2.02
# SpRet_Std                                       Coef          0.47
#                                                 Tstat         0.96
# SpRet_Sum                                       Coef          0.04
#                                                 Tstat         1.76
# UnemploymentRate                                Coef         -0.03
#                                                 Tstat        -0.18
# AbRetStd                                        Coef         -0.19
#                                                 Tstat        -2.99
# Runup                                           Coef         -0.04
#                                                 Tstat        -7.07
# Leverage                                        Coef         -0.12
#                                                 Tstat        -0.24
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -1.07
# SaleGrowth_LowQuant                             Coef          0.65
#                                                 Tstat         1.66
# SaleGrowth_UppQuant                             Coef          0.17
#                                                 Tstat         0.57
# Size_LowQuant                                   Coef          1.25
#                                                 Tstat         1.56
# Size_UppQuant                                   Coef          1.01
#                                                 Tstat         3.06
# RegInfo                                         Obs        2519.00
#                                                 R2            0.04
#
#                                                                     \
#                                                       (1993, 1999)
# Ms                                              Coef         -7.07
#                                                 Tstat        -3.06
# const                                           Coef         -4.26
#                                                 Tstat        -1.68
# GdpGrowth                                       Coef         -0.02
#                                                 Tstat        -0.18
# Inflation                                       Coef          1.27
#                                                 Tstat         1.90
# SpRet_Std                                       Coef          1.17
#                                                 Tstat         1.38
# SpRet_Sum                                       Coef          0.07
#                                                 Tstat         1.88
# UnemploymentRate                                Coef         -0.22
#                                                 Tstat        -0.68
# AbRetStd                                        Coef         -0.16
#                                                 Tstat        -1.65
# Runup                                           Coef         -0.04
#                                                 Tstat        -5.75
# Leverage                                        Coef         -0.81
#                                                 Tstat        -1.12
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.00
#                                                 Tstat        -0.46
# SaleGrowth_LowQuant                             Coef          0.55
#                                                 Tstat         1.07
# SaleGrowth_UppQuant                             Coef          0.23
#                                                 Tstat         0.61
# Size_LowQuant                                   Coef          0.62
#                                                 Tstat         0.69
# Size_UppQuant                                   Coef          1.56
#                                                 Tstat         3.39
# RegInfo                                         Obs        1380.00
#                                                 R2            0.05
#
#                                                                     \
#                                                       (2000, 2007)
# Ms                                              Coef         -0.25
#                                                 Tstat        -0.13
# const                                           Coef         -4.52
#                                                 Tstat        -1.92
# GdpGrowth                                       Coef          0.09
#                                                 Tstat         0.93
# Inflation                                       Coef          0.65
#                                                 Tstat         1.96
# SpRet_Std                                       Coef          0.54
#                                                 Tstat         0.75
# SpRet_Sum                                       Coef          0.01
#                                                 Tstat         0.35
# UnemploymentRate                                Coef          0.07
#                                                 Tstat         0.20
# AbRetStd                                        Coef         -0.23
#                                                 Tstat        -2.46
# Runup                                           Coef         -0.04
#                                                 Tstat        -4.30
# Leverage                                        Coef          0.42
#                                                 Tstat         0.65
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.02
#                                                 Tstat        -1.23
# SaleGrowth_LowQuant                             Coef          0.64
#                                                 Tstat         1.06
# SaleGrowth_UppQuant                             Coef         -0.03
#                                                 Tstat        -0.06
# Size_LowQuant                                   Coef          3.38
#                                                 Tstat         2.00
# Size_UppQuant                                   Coef          0.58
#                                                 Tstat         1.20
# RegInfo                                         Obs        1139.00
#                                                 R2            0.04
#
#                                                           30d_MsRR  \
#                                                       (1983, 2007)
# Ms                                              Coef         -0.71
#                                                 Tstat        -0.90
# const                                           Coef         -1.96
#                                                 Tstat        -2.77
# GdpGrowth                                       Coef          0.01
#                                                 Tstat         0.18
# Inflation                                       Coef          0.06
#                                                 Tstat         0.35
# SpRet_Std                                       Coef          0.18
#                                                 Tstat         0.54
# SpRet_Sum                                       Coef          0.01
#                                                 Tstat         0.56
# UnemploymentRate                                Coef         -0.11
#                                                 Tstat        -1.26
# AbRetStd                                        Coef         -0.11
#                                                 Tstat        -2.24
# Runup                                           Coef         -0.04
#                                                 Tstat        -8.99
# Leverage                                        Coef         -0.02
#                                                 Tstat        -0.04
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -0.78
# SaleGrowth_LowQuant                             Coef          0.56
#                                                 Tstat         1.70
# SaleGrowth_UppQuant                             Coef          0.01
#                                                 Tstat         0.04
# Size_LowQuant                                   Coef          1.22
#                                                 Tstat         1.81
# Size_UppQuant                                   Coef          0.71
#                                                 Tstat         2.57
# RegInfo                                         Obs        3512.00
#                                                 R2            0.03
#
#                                                                     \
#                                                       (1983, 1999)
# Ms                                              Coef         -1.55
#                                                 Tstat        -1.60
# const                                           Coef         -1.81
#                                                 Tstat        -2.22
# GdpGrowth                                       Coef         -0.04
#                                                 Tstat        -0.61
# Inflation                                       Coef         -0.02
#                                                 Tstat        -0.08
# SpRet_Std                                       Coef          0.54
#                                                 Tstat         1.39
# SpRet_Sum                                       Coef         -0.00
#                                                 Tstat        -0.01
# UnemploymentRate                                Coef         -0.12
#                                                 Tstat        -1.01
# AbRetStd                                        Coef         -0.05
#                                                 Tstat        -0.80
# Runup                                           Coef         -0.04
#                                                 Tstat        -7.79
# Leverage                                        Coef         -0.34
#                                                 Tstat        -0.57
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -0.82
# SaleGrowth_LowQuant                             Coef          0.55
#                                                 Tstat         1.42
# SaleGrowth_UppQuant                             Coef          0.04
#                                                 Tstat         0.12
# Size_LowQuant                                   Coef          1.06
#                                                 Tstat         1.53
# Size_UppQuant                                   Coef          0.80
#                                                 Tstat         2.39
# RegInfo                                         Obs        2373.00
#                                                 R2            0.03
#
#                                                                     \
#                                                       (2000, 2007)
# Ms                                              Coef          0.14
#                                                 Tstat         0.09
# const                                           Coef         -2.37
#                                                 Tstat        -1.00
# GdpGrowth                                       Coef          0.06
#                                                 Tstat         0.64
# Inflation                                       Coef          0.17
#                                                 Tstat         0.48
# SpRet_Std                                       Coef         -0.08
#                                                 Tstat        -0.11
# SpRet_Sum                                       Coef         -0.00
#                                                 Tstat        -0.12
# UnemploymentRate                                Coef         -0.04
#                                                 Tstat        -0.12
# AbRetStd                                        Coef         -0.22
#                                                 Tstat        -2.34
# Runup                                           Coef         -0.04
#                                                 Tstat        -4.24
# Leverage                                        Coef          0.34
#                                                 Tstat         0.46
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -0.49
# SaleGrowth_LowQuant                             Coef          0.51
#                                                 Tstat         0.84
# SaleGrowth_UppQuant                             Coef         -0.02
#                                                 Tstat        -0.05
# Size_LowQuant                                   Coef          2.08
#                                                 Tstat         0.84
# Size_UppQuant                                   Coef          0.63
#                                                 Tstat         1.26
# RegInfo                                         Obs        1139.00
#                                                 R2            0.04
#
#                                                           90d_MsRR  \
#                                                       (1983, 2007)
# Ms                                              Coef         -0.97
#                                                 Tstat        -2.14
# const                                           Coef         -2.22
#                                                 Tstat        -3.20
# GdpGrowth                                       Coef          0.05
#                                                 Tstat         1.12
# Inflation                                       Coef          0.39
#                                                 Tstat         2.33
# SpRet_Std                                       Coef         -0.03
#                                                 Tstat        -0.09
# SpRet_Sum                                       Coef          0.01
#                                                 Tstat         0.75
# UnemploymentRate                                Coef         -0.18
#                                                 Tstat        -1.98
# AbRetStd                                        Coef         -0.11
#                                                 Tstat        -2.14
# Runup                                           Coef         -0.04
#                                                 Tstat        -9.11
# Leverage                                        Coef         -0.08
#                                                 Tstat        -0.19
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -1.18
# SaleGrowth_LowQuant                             Coef          0.68
#                                                 Tstat         2.08
# SaleGrowth_UppQuant                             Coef          0.14
#                                                 Tstat         0.57
# Size_LowQuant                                   Coef          1.02
#                                                 Tstat         1.63
# Size_UppQuant                                   Coef          0.77
#                                                 Tstat         2.79
# RegInfo                                         Obs        3506.00
#                                                 R2            0.03
#
#                                                                     \
#                                                       (1983, 1999)
# Ms                                              Coef         -2.07
#                                                 Tstat        -3.60
# const                                           Coef         -1.60
#                                                 Tstat        -1.95
# GdpGrowth                                       Coef         -0.01
#                                                 Tstat        -0.16
# Inflation                                       Coef          0.31
#                                                 Tstat         1.44
# SpRet_Std                                       Coef          0.11
#                                                 Tstat         0.32
# SpRet_Sum                                       Coef         -0.00
#                                                 Tstat        -0.08
# UnemploymentRate                                Coef         -0.20
#                                                 Tstat        -1.66
# AbRetStd                                        Coef         -0.04
#                                                 Tstat        -0.70
# Runup                                           Coef         -0.04
#                                                 Tstat        -7.92
# Leverage                                        Coef         -0.54
#                                                 Tstat        -0.93
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -0.80
# SaleGrowth_LowQuant                             Coef          0.61
#                                                 Tstat         1.59
# SaleGrowth_UppQuant                             Coef          0.14
#                                                 Tstat         0.47
# Size_LowQuant                                   Coef          0.54
#                                                 Tstat         0.81
# Size_UppQuant                                   Coef          0.92
#                                                 Tstat         2.75
# RegInfo                                         Obs        2367.00
#                                                 R2            0.04
#
#
#                                                       (2000, 2007)
# Ms                                              Coef          0.22
#                                                 Tstat         0.26
# const                                           Coef         -4.39
#                                                 Tstat        -1.94
# GdpGrowth                                       Coef          0.09
#                                                 Tstat         0.90
# Inflation                                       Coef          0.60
#                                                 Tstat         1.61
# SpRet_Std                                       Coef          0.60
#                                                 Tstat         0.80
# SpRet_Sum                                       Coef          0.01
#                                                 Tstat         0.33
# UnemploymentRate                                Coef          0.05
#                                                 Tstat         0.18
# AbRetStd                                        Coef         -0.23
#                                                 Tstat        -2.49
# Runup                                           Coef         -0.04
#                                                 Tstat        -4.31
# Leverage                                        Coef          0.42
#                                                 Tstat         0.65
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.02
#                                                 Tstat        -1.23
# SaleGrowth_LowQuant                             Coef          0.64
#                                                 Tstat         1.05
# SaleGrowth_UppQuant                             Coef         -0.03
#                                                 Tstat        -0.07
# Size_LowQuant                                   Coef          3.39
#                                                 Tstat         2.01
# Size_UppQuant                                   Coef          0.57
#                                                 Tstat         1.18
# RegInfo                                         Obs        1139.00
#                                                 R2            0.04

# %% [markdown]
# ## Issuance Date Study

# %%
display(np.round(TempTable_I,2))
# Out:
#                                                       30d_MsWideHF  \
#                                                       (1993, 2007)
# Ms                                              Coef         -0.50
#                                                 Tstat        -0.18
# const                                           Coef          0.41
#                                                 Tstat         0.23
# GdpGrowth                                       Coef         -0.26
#                                                 Tstat        -3.26
# Inflation                                       Coef         -0.42
#                                                 Tstat        -1.60
# SpRet_Std                                       Coef         -0.11
#                                                 Tstat        -0.18
# SpRet_Sum                                       Coef         -0.02
#                                                 Tstat        -0.87
# UnemploymentRate                                Coef          0.31
#                                                 Tstat         1.49
# AbRetStd                                        Coef         -0.34
#                                                 Tstat        -4.85
# Runup                                           Coef         -0.07
#                                                 Tstat       -10.94
# Leverage                                        Coef         -0.90
#                                                 Tstat        -1.49
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.02
#                                                 Tstat        -1.77
# SaleGrowth_LowQuant                             Coef         -0.50
#                                                 Tstat        -1.07
# SaleGrowth_UppQuant                             Coef          0.18
#                                                 Tstat         0.55
# Size_LowQuant                                   Coef         -1.72
#                                                 Tstat        -1.73
# Size_UppQuant                                   Coef          0.17
#                                                 Tstat         0.44
# RegInfo                                         Obs        2561.00
#                                                 R2            0.07
#
#                                                                     \
#                                                       (1993, 1999)
# Ms                                              Coef        -10.50
#                                                 Tstat        -2.42
# const                                           Coef          0.31
#                                                 Tstat         0.12
# GdpGrowth                                       Coef         -0.29
#                                                 Tstat        -2.15
# Inflation                                       Coef         -0.81
#                                                 Tstat        -1.18
# SpRet_Std                                       Coef         -0.28
#                                                 Tstat        -0.29
# SpRet_Sum                                       Coef         -0.04
#                                                 Tstat        -1.01
# UnemploymentRate                                Coef          0.41
#                                                 Tstat         1.02
# AbRetStd                                        Coef         -0.27
#                                                 Tstat        -2.86
# Runup                                           Coef         -0.07
#                                                 Tstat        -7.65
# Leverage                                        Coef         -1.03
#                                                 Tstat        -1.17
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.03
#                                                 Tstat        -2.02
# SaleGrowth_LowQuant                             Coef         -0.35
#                                                 Tstat        -0.56
# SaleGrowth_UppQuant                             Coef          0.34
#                                                 Tstat         0.79
# Size_LowQuant                                   Coef         -1.04
#                                                 Tstat        -0.97
# Size_UppQuant                                   Coef          1.36
#                                                 Tstat         2.56
# RegInfo                                         Obs        1402.00
#                                                 R2            0.07
#
#                                                                     \
#                                                       (2000, 2007)
# Ms                                              Coef          6.52
#                                                 Tstat         1.67
# const                                           Coef          0.41
#                                                 Tstat         0.15
# GdpGrowth                                       Coef         -0.30
#                                                 Tstat        -2.75
# Inflation                                       Coef         -0.65
#                                                 Tstat        -1.66
# SpRet_Std                                       Coef         -0.69
#                                                 Tstat        -0.80
# SpRet_Sum                                       Coef         -0.04
#                                                 Tstat        -1.01
# UnemploymentRate                                Coef          0.63
#                                                 Tstat         1.71
# AbRetStd                                        Coef         -0.33
#                                                 Tstat        -2.86
# Runup                                           Coef         -0.07
#                                                 Tstat        -7.97
# Leverage                                        Coef         -1.06
#                                                 Tstat        -1.27
# OfferedTotalSharesDivByCommonShares_Outstanding Coef          0.01
#                                                 Tstat         0.35
# SaleGrowth_LowQuant                             Coef         -0.72
#                                                 Tstat        -1.01
# SaleGrowth_UppQuant                             Coef          0.01
#                                                 Tstat         0.01
# Size_LowQuant                                   Coef         -3.41
#                                                 Tstat        -1.49
# Size_UppQuant                                   Coef         -0.96
#                                                 Tstat        -1.74
# RegInfo                                         Obs        1159.00
#                                                 R2            0.09
#
#                                                       90d_MsWideHF  \
#                                                       (1993, 2007)
# Ms                                              Coef         -2.79
#                                                 Tstat        -1.62
# const                                           Coef          0.23
#                                                 Tstat         0.13
# GdpGrowth                                       Coef         -0.12
#                                                 Tstat        -1.51
# Inflation                                       Coef         -0.03
#                                                 Tstat        -0.11
# SpRet_Std                                       Coef         -0.45
#                                                 Tstat        -0.80
# SpRet_Sum                                       Coef         -0.11
#                                                 Tstat        -4.21
# UnemploymentRate                                Coef          0.20
#                                                 Tstat         0.95
# AbRetStd                                        Coef         -0.33
#                                                 Tstat        -4.75
# Runup                                           Coef         -0.07
#                                                 Tstat       -11.40
# Leverage                                        Coef         -1.13
#                                                 Tstat        -1.94
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.02
#                                                 Tstat        -1.44
# SaleGrowth_LowQuant                             Coef         -0.35
#                                                 Tstat        -0.77
# SaleGrowth_UppQuant                             Coef          0.03
#                                                 Tstat         0.11
# Size_LowQuant                                   Coef         -1.79
#                                                 Tstat        -1.88
# Size_UppQuant                                   Coef          0.37
#                                                 Tstat         0.96
# RegInfo                                         Obs        2560.00
#                                                 R2            0.08
#
#                                                                     \
#                                                       (1993, 1999)
# Ms                                              Coef         -7.80
#                                                 Tstat        -2.98
# const                                           Coef          1.37
#                                                 Tstat         0.47
# GdpGrowth                                       Coef          0.11
#                                                 Tstat         0.88
# Inflation                                       Coef          1.03
#                                                 Tstat         1.37
# SpRet_Std                                       Coef         -1.42
#                                                 Tstat        -1.45
# SpRet_Sum                                       Coef         -0.10
#                                                 Tstat        -2.30
# UnemploymentRate                                Coef         -0.45
#                                                 Tstat        -1.21
# AbRetStd                                        Coef         -0.26
#                                                 Tstat        -2.76
# Runup                                           Coef         -0.07
#                                                 Tstat        -7.71
# Leverage                                        Coef         -0.54
#                                                 Tstat        -0.63
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.03
#                                                 Tstat        -2.02
# SaleGrowth_LowQuant                             Coef         -0.27
#                                                 Tstat        -0.44
# SaleGrowth_UppQuant                             Coef         -0.29
#                                                 Tstat        -0.68
# Size_LowQuant                                   Coef         -1.35
#                                                 Tstat        -1.29
# Size_UppQuant                                   Coef          1.16
#                                                 Tstat         2.17
# RegInfo                                         Obs        1402.00
#                                                 R2            0.08
#
#                                                                     \
#                                                       (2000, 2007)
# Ms                                              Coef          1.49
#                                                 Tstat         0.63
# const                                           Coef         -2.21
#                                                 Tstat        -0.82
# GdpGrowth                                       Coef         -0.29
#                                                 Tstat        -2.64
# Inflation                                       Coef          0.10
#                                                 Tstat         0.26
# SpRet_Std                                       Coef         -0.38
#                                                 Tstat        -0.47
# SpRet_Sum                                       Coef         -0.13
#                                                 Tstat        -3.69
# UnemploymentRate                                Coef          0.74
#                                                 Tstat         1.96
# AbRetStd                                        Coef         -0.31
#                                                 Tstat        -2.74
# Runup                                           Coef         -0.08
#                                                 Tstat        -8.60
# Leverage                                        Coef         -1.87
#                                                 Tstat        -2.33
# OfferedTotalSharesDivByCommonShares_Outstanding Coef          0.01
#                                                 Tstat         0.34
# SaleGrowth_LowQuant                             Coef         -0.36
#                                                 Tstat        -0.53
# SaleGrowth_UppQuant                             Coef          0.55
#                                                 Tstat         1.08
# Size_LowQuant                                   Coef         -2.46
#                                                 Tstat        -1.17
# Size_UppQuant                                   Coef         -0.39
#                                                 Tstat        -0.72
# RegInfo                                         Obs        1158.00
#                                                 R2            0.10
#
#                                                           30d_MsRR  \
#                                                       (1970, 2007)
# Ms                                              Coef         -0.10
#                                                 Tstat        -0.21
# const                                           Coef         -0.19
#                                                 Tstat        -0.30
# GdpGrowth                                       Coef         -0.09
#                                                 Tstat        -2.23
# Inflation                                       Coef          0.11
#                                                 Tstat         1.36
# SpRet_Std                                       Coef         -0.18
#                                                 Tstat        -0.53
# SpRet_Sum                                       Coef         -0.04
#                                                 Tstat        -2.55
# UnemploymentRate                                Coef          0.08
#                                                 Tstat         1.06
# AbRetStd                                        Coef         -0.34
#                                                 Tstat        -6.40
# Runup                                           Coef         -0.06
#                                                 Tstat       -12.93
# Leverage                                        Coef         -0.70
#                                                 Tstat        -1.48
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -1.07
# SaleGrowth_LowQuant                             Coef         -0.27
#                                                 Tstat        -0.81
# SaleGrowth_UppQuant                             Coef          0.04
#                                                 Tstat         0.17
# Size_LowQuant                                   Coef         -2.22
#                                                 Tstat        -3.58
# Size_UppQuant                                   Coef          0.22
#                                                 Tstat         0.81
# RegInfo                                         Obs        4038.00
#                                                 R2            0.06
#
#                                                                     \
#                                                       (1970, 1999)
# Ms                                              Coef          0.34
#                                                 Tstat         0.69
# const                                           Coef         -0.45
#                                                 Tstat        -0.60
# GdpGrowth                                       Coef         -0.04
#                                                 Tstat        -0.93
# Inflation                                       Coef          0.20
#                                                 Tstat         2.50
# SpRet_Std                                       Coef         -0.22
#                                                 Tstat        -0.55
# SpRet_Sum                                       Coef         -0.04
#                                                 Tstat        -1.92
# UnemploymentRate                                Coef         -0.01
#                                                 Tstat        -0.15
# AbRetStd                                        Coef         -0.28
#                                                 Tstat        -4.60
# Runup                                           Coef         -0.06
#                                                 Tstat        -9.75
# Leverage                                        Coef         -0.46
#                                                 Tstat        -0.78
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -1.32
# SaleGrowth_LowQuant                             Coef         -0.17
#                                                 Tstat        -0.47
# SaleGrowth_UppQuant                             Coef          0.04
#                                                 Tstat         0.14
# Size_LowQuant                                   Coef         -2.07
#                                                 Tstat        -3.34
# Size_UppQuant                                   Coef          0.71
#                                                 Tstat         2.29
# RegInfo                                         Obs        2879.00
#                                                 R2            0.05
#
#                                                                     \
#                                                       (2000, 2007)
# Ms                                              Coef         -2.42
#                                                 Tstat        -1.36
# const                                           Coef         -0.32
#                                                 Tstat        -0.12
# GdpGrowth                                       Coef         -0.26
#                                                 Tstat        -2.39
# Inflation                                       Coef         -0.48
#                                                 Tstat        -1.18
# SpRet_Std                                       Coef         -0.94
#                                                 Tstat        -1.07
# SpRet_Sum                                       Coef         -0.04
#                                                 Tstat        -1.00
# UnemploymentRate                                Coef          0.71
#                                                 Tstat         1.96
# AbRetStd                                        Coef         -0.32
#                                                 Tstat        -2.84
# Runup                                           Coef         -0.07
#                                                 Tstat        -7.86
# Leverage                                        Coef         -1.22
#                                                 Tstat        -1.46
# OfferedTotalSharesDivByCommonShares_Outstanding Coef          0.01
#                                                 Tstat         0.32
# SaleGrowth_LowQuant                             Coef         -0.66
#                                                 Tstat        -0.93
# SaleGrowth_UppQuant                             Coef          0.04
#                                                 Tstat         0.08
# Size_LowQuant                                   Coef         -3.14
#                                                 Tstat        -1.37
# Size_UppQuant                                   Coef         -0.92
#                                                 Tstat        -1.66
# RegInfo                                         Obs        1159.00
#                                                 R2            0.09
#
#                                                           90d_MsRR  \
#                                                       (1970, 2007)
# Ms                                              Coef         -0.21
#                                                 Tstat        -0.76
# const                                           Coef         -0.19
#                                                 Tstat        -0.28
# GdpGrowth                                       Coef         -0.05
#                                                 Tstat        -1.23
# Inflation                                       Coef          0.20
#                                                 Tstat         2.59
# SpRet_Std                                       Coef         -0.40
#                                                 Tstat        -1.33
# SpRet_Sum                                       Coef         -0.10
#                                                 Tstat        -5.84
# UnemploymentRate                                Coef          0.07
#                                                 Tstat         0.84
# AbRetStd                                        Coef         -0.33
#                                                 Tstat        -6.26
# Runup                                           Coef         -0.06
#                                                 Tstat       -13.34
# Leverage                                        Coef         -0.84
#                                                 Tstat        -1.82
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.00
#                                                 Tstat        -0.58
# SaleGrowth_LowQuant                             Coef          0.01
#                                                 Tstat         0.05
# SaleGrowth_UppQuant                             Coef         -0.05
#                                                 Tstat        -0.22
# Size_LowQuant                                   Coef         -2.14
#                                                 Tstat        -3.57
# Size_UppQuant                                   Coef          0.34
#                                                 Tstat         1.24
# RegInfo                                         Obs        4031.00
#                                                 R2            0.07
#
#                                                                     \
#                                                       (1970, 1999)
# Ms                                              Coef          0.20
#                                                 Tstat         0.69
# const                                           Coef         -0.55
#                                                 Tstat        -0.75
# GdpGrowth                                       Coef          0.02
#                                                 Tstat         0.55
# Inflation                                       Coef          0.28
#                                                 Tstat         3.51
# SpRet_Std                                       Coef         -0.51
#                                                 Tstat        -1.56
# SpRet_Sum                                       Coef         -0.07
#                                                 Tstat        -3.74
# UnemploymentRate                                Coef         -0.03
#                                                 Tstat        -0.32
# AbRetStd                                        Coef         -0.26
#                                                 Tstat        -4.29
# Runup                                           Coef         -0.06
#                                                 Tstat        -9.75
# Leverage                                        Coef         -0.12
#                                                 Tstat        -0.20
# OfferedTotalSharesDivByCommonShares_Outstanding Coef         -0.01
#                                                 Tstat        -1.16
# SaleGrowth_LowQuant                             Coef          0.18
#                                                 Tstat         0.49
# SaleGrowth_UppQuant                             Coef         -0.31
#                                                 Tstat        -1.13
# Size_LowQuant                                   Coef         -2.00
#                                                 Tstat        -3.35
# Size_UppQuant                                   Coef          0.63
#                                                 Tstat         2.01
# RegInfo                                         Obs        2873.00
#                                                 R2            0.06
#
#
#                                                       (2000, 2007)
# Ms                                              Coef         -2.17
#                                                 Tstat        -2.21
# const                                           Coef         -3.04
#                                                 Tstat        -1.17
# GdpGrowth                                       Coef         -0.26
#                                                 Tstat        -2.41
# Inflation                                       Coef          0.56
#                                                 Tstat         1.33
# SpRet_Std                                       Coef         -1.10
#                                                 Tstat        -1.27
# SpRet_Sum                                       Coef         -0.13
#                                                 Tstat        -3.63
# UnemploymentRate                                Coef          0.79
#                                                 Tstat         2.24
# AbRetStd                                        Coef         -0.28
#                                                 Tstat        -2.47
# Runup                                           Coef         -0.08
#                                                 Tstat        -8.62
# Leverage                                        Coef         -1.90
#                                                 Tstat        -2.37
# OfferedTotalSharesDivByCommonShares_Outstanding Coef          0.00
#                                                 Tstat         0.26
# SaleGrowth_LowQuant                             Coef         -0.41
#                                                 Tstat        -0.59
# SaleGrowth_UppQuant                             Coef          0.57
#                                                 Tstat         1.11
# Size_LowQuant                                   Coef         -2.43
#                                                 Tstat        -1.15
# Size_UppQuant                                   Coef         -0.31
#                                                 Tstat        -0.57
# RegInfo                                         Obs        1158.00
#                                                 R2            0.11
